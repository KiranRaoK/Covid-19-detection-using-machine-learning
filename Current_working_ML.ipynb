# %%
import pandas as pd
import numpy as np

# %%
file=open("data.txt",'r')
data=list()
for i in file:
    line=i.split()
    data.append(line)
datawh=data[1:]
df=pd.DataFrame(datawh)
df.columns=['Breathlessness',
 'Sore_throat',
 'Fever',
 'Cough',
 'Dry_Cough',
 'Muscle_pain',
 'Fatigue',
 'Diarrhea',
 'Sneezing',
 'Covid_Presence']
df.head(5)
# Out:
#   Breathlessness Sore_throat Fever Cough Dry_Cough Muscle_pain   Fatigue  \
# 0           Mild        None  None  Mild      Mild        Mild      Mild
# 1           Mild        None  None  Mild      Mild        Mild      Mild
# 2           Mild        None  None  Mild      Mild        Mild      Mild
# 3           Mild        None  None  Mild      Mild        Mild  Moderate
# 4           Mild        None  None  Mild      Mild        Mild  Moderate
#
#   Diarrhea  Sneezing Covid_Presence
# 0     None      Mild              1
# 1     None  Moderate              1
# 2     None    Severe              1
# 3     None      Mild              1
# 4     None  Moderate              1

# %%
from sklearn import preprocessing as p
LE=p.LabelEncoder()
df['Covid_Presence']=LE.fit_transform(df['Covid_Presence'])
df[['Breathlessness']]=LE.fit_transform(df[['Breathlessness']])
df[['Sore_throat']]=LE.fit_transform(df[['Sore_throat']])
df[['Fever']]=LE.fit_transform(df[['Fever']])
df[[ 'Cough']]=LE.fit_transform(df[[ 'Cough']])
df[['Dry_Cough']]=LE.fit_transform(df[['Dry_Cough']])
df[[ 'Muscle_pain']]=LE.fit_transform(df[[ 'Muscle_pain']])
df[[ 'Fatigue']]=LE.fit_transform(df[[ 'Fatigue']])
df[[ 'Diarrhea']]=LE.fit_transform(df[[ 'Diarrhea']])
df[[ 'Sneezing']]=LE.fit_transform(df[[ 'Sneezing']])
df.head()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/preprocessing/label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#    Breathlessness  Sore_throat  Fever  Cough  Dry_Cough  Muscle_pain  Fatigue  \
# 0               0            2      2      0          0            0        0
# 1               0            2      2      0          0            0        0
# 2               0            2      2      0          0            0        0
# 3               0            2      2      0          0            0        1
# 4               0            2      2      0          0            0        1
#
#    Diarrhea  Sneezing  Covid_Presence
# 0         2         0               1
# 1         2         1               1
# 2         2         3               1
# 3         2         0               1
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
knn = KNeighborsClassifier(n_neighbors = 135)
X=df[['Breathlessness',
 'Sore_throat',
 'Fever',
 'Cough',
 'Dry_Cough',
 'Muscle_pain',
 'Fatigue',
 'Diarrhea',
 'Sneezing']]
y=df['Covid_Presence']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
knn.fit(X_train, y_train)  
print(knn.score(X_test, y_test))
print(knn.score(X_train, y_train))
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
print('''
None------>0
Mild------>1
Moderate------->2
Severe------->3''')
temp={0:'None',1:'Mild',2:'Moderate',3:'Severe'}
rest={'Mild':0,'None':2,'Moderate':1,'Severe':3}
finallist=list()
print("Enter the severity of following symptoms")
print('Breathlessness :')
a1=int(input())
finallist.append(rest[temp[a1]])
print('Sore_throat :')
a2=int(input())
finallist.append(rest[temp[a2]])
print('Fever :')
a3=int(input())
finallist.append(rest[temp[a3]])
print('Cough :')
a4=int(input())
finallist.append(rest[temp[a4]])
print('Dry_Cough :')
a5=int(input())
finallist.append(rest[temp[a5]])
print('Muscle_pain :')
a6=int(input())
finallist.append(rest[temp[a6]])
print('Fatigue :')
a7=int(input())
finallist.append(rest[temp[a7]])
print('Diarrhea :')
a8=int(input())
finallist.append(rest[temp[a8]])
print('Sneezing :')
a9=int(input())
finallist.append(rest[temp[a9]])
a=knn.predict([finallist])
if a[0]==0:
    print("Covid 19 Negative")
else:
    print("Covid 19 Positive")
# Out:
# None------>0
# Mild------>1
# Moderate------->2
# Severe------->3
# Enter the severity of following symptoms
# Breathlessness :
#  0
# Sore_throat :
#  1
# Fever :
#  0
# Cough :
#  0
# Dry_Cough :
#  0
# Muscle_pain :
#  0
# Fatigue :
#  0
# Diarrhea :
#  0
# Sneezing :
#  0
# Covid 19 Negative
